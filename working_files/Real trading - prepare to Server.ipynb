# %%
import requests
import numpy as np
import pandas as pd
import statsmodels.api as sm
import matplotlib.pyplot as plt
import copy
import time
import random

from binance import Client, ThreadedWebsocketManager, ThreadedDepthCacheManager
from futures_sign import send_signed_request, send_public_request
from cred import KEY, SECRET

# %%
symbol='ETHUSDT'
client = Client(KEY, SECRET)

maxposition=0.01
stop_percent=0.01 # 0.01=1%
eth_proffit_array=[[20,1],[40,1],[60,2],[80,2],[100,2],[150,1],[200,1],[200,0]]
proffit_array=copy.copy(eth_proffit_array)

pointer=str(random.randint(1000, 9999))

# %%
# Get last 500 kandels 5 minutes for Symbol

def get_futures_klines(symbol,limit=500):
    x = requests.get('https://binance.com/fapi/v1/klines?symbol='+symbol+'&limit='+str(limit)+'&interval=5m')
    df=pd.DataFrame(x.json())
    df.columns=['open_time','open','high','low','close','volume','close_time','d1','d2','d3','d4','d5']
    df=df.drop(['d1','d2','d3','d4','d5'],axis=1)
    df['open']=df['open'].astype(float)
    df['high']=df['high'].astype(float)
    df['low']=df['low'].astype(float)
    df['close']=df['close'].astype(float)
    df['volume']=df['volume'].astype(float)
    return(df)

# %%
# Open position for Sybol with 

def open_position(symbol,s_l,quantity_l):
    prt('open: '+symbol+' quantity: '+str(quantity_l))
    sprice=get_symbol_price(symbol)

    if(s_l=='long'):
        close_price=str(round(sprice*(1+0.01),2))
        params = {
            "batchOrders": [
                {
                    "symbol":symbol,
                    "side": "BUY",
                    "type": "LIMIT",
                    "quantity": str(quantity_l),
                    "timeInForce":"GTC",
                    "price": close_price        

                }
            ]
        }
        responce = send_signed_request('POST', '/fapi/v1/batchOrders', params)
       
       
    if(s_l=='short'):
        close_price=str(round(sprice*(1-0.01),2))
        params = {
            "batchOrders": [
                {
                    "symbol":symbol,
                    "side": "SELL",
                    "type": "LIMIT",
                    "quantity": str(quantity_l),
                    "timeInForce":"GTC",
                    "price": close_price
                }
           ]
        }
        responce = send_signed_request('POST', '/fapi/v1/batchOrders', params)

# %%
# Close position for symbol with quantity

def close_position(symbol,s_l,quantity_l):
    prt('close: '+symbol+' quantity: '+str(quantity_l))

    sprice=get_symbol_price(symbol)

    if(s_l=='long'):
        close_price=str(round(sprice*(1-0.01),2))
        params = {
                    "symbol":symbol,
                    "side": "SELL",
                    "type": "LIMIT",
                    "quantity": str(quantity_l),
                    "timeInForce":"GTC",
                    "price": close_price
                }
        responce = send_signed_request('POST', '/fapi/v1/order', params)
        print (responce)

    if(s_l=='short'):
        close_price=str(round(sprice*(1+0.01),2))
        params = {
                
                    "symbol":symbol,
                    "side": "BUY",
                    "type": "LIMIT",
                    "quantity": str(quantity_l),
                    "timeInForce":"GTC",
                    "price": close_price        
                }
        responce = send_signed_request('POST', '/fapi/v1/order', params)
        print (responce)

# %%
# Find all opened positions

def get_opened_positions(symbol):
    status = client.futures_account()
    positions=pd.DataFrame(status['positions'])
    a = positions[positions['symbol']==symbol]['positionAmt'].astype(float).tolist()[0]
    leverage = int(positions[positions['symbol']==symbol]['leverage'])
    entryprice = positions[positions['symbol']==symbol]['entryPrice']
    profit = float(status['totalUnrealizedProfit'])
    balance = round(float(status['totalWalletBalance']),2)
    if a>0:
        pos = "long"
    elif a<0:
        pos = "short"
    else: 
        pos = ""
    return([pos,a,profit,leverage,balance,round(float(entryprice),3),0])

# %%
# Close all orders 

def check_and_close_orders(symbol):
    global isStop 
    a=client.futures_get_open_orders(symbol=symbol)
    if len(a)>0:
        isStop = False
        client.futures_cancel_all_open_orders(symbol=symbol)

# %%
def get_symbol_price(symbol):
    prices = client.get_all_tickers()
    df=pd.DataFrame(prices)
    return float(df[ df['symbol']==symbol]['price'])

# %%
# INDICATORS

# %%
# To find a slope of price line 
def indSlope(series,n):
    
    array_sl = [j*0 for j in range(n-1)]
    
    for j in range(n,len(series)+1):
        y = series[j-n:j]
        x = np.array(range(n))
        x_sc = (x - x.min())/(x.max() - x.min())
        y_sc = (y - y.min())/(y.max() - y.min())
        x_sc = sm.add_constant(x_sc)
        model = sm.OLS(y_sc,x_sc)
        results = model.fit()
        array_sl.append(results.params[-1])
    slope_angle = (np.rad2deg(np.arctan(np.array(array_sl))))
    return np.array(slope_angle)

# %%
# True Range and Average True Range indicator

def indATR(source_DF,n):
    df = source_DF.copy()
    df['H-L']=abs(df['high']-df['low'])
    df['H-PC']=abs(df['high']-df['close'].shift(1))
    df['L-PC']=abs(df['low']-df['close'].shift(1))
    df['TR']=df[['H-L','H-PC','L-PC']].max(axis=1,skipna=False)
    df['ATR'] = df['TR'].rolling(n).mean()
    df_temp = df.drop(['H-L','H-PC','L-PC'],axis=1)
    return df_temp

# %%
# find local mimimum / local maximum

def isLCC(DF,i):
    df=DF.copy()
    LCC=0
    
    if df['close'][i]<=df['close'][i+1] and df['close'][i]<=df['close'][i-1] and df['close'][i+1]>df['close'][i-1]:
        #найдено Дно
        LCC = i-1;
    return LCC

def isHCC(DF,i):
    df=DF.copy()
    HCC=0
    if df['close'][i]>=df['close'][i+1] and df['close'][i]>=df['close'][i-1] and df['close'][i+1]<df['close'][i-1]:
        #найдена вершина
        HCC = i;
    return HCC

# %%
def getMaxMinChannel(DF, n):
    maxx=0
    minn=DF['low'].max()
    for i in range (1,n):
        if maxx<DF['high'][len(DF)-i]:
            maxx=DF['high'][len(DF)-i]
        if minn>DF['low'][len(DF)-i]:
            minn=DF['low'][len(DF)-i]
    return(maxx,minn)

# %%
# generate data frame with all needed data

def PrepareDF(DF):
    ohlc = DF.iloc[:,[0,1,2,3,4,5]]
    ohlc.columns = ["date","open","high","low","close","volume"]
    ohlc=ohlc.set_index('date')
    df = indATR(ohlc,14).reset_index()
    df['slope'] = indSlope(df['close'],5)
    df['channel_max'] = df['high'].rolling(10).max()
    df['channel_min'] = df['low'].rolling(10).min()
    df['position_in_channel'] = (df['close']-df['channel_min']) / (df['channel_max']-df['channel_min'])
    df = df.set_index('date')
    df = df.reset_index()
    return(df)

# %%
def check_if_signal(symbol):
    ohlc = get_futures_klines(symbol,100)
    prepared_df = PrepareDF(ohlc)
    signal="" # return value
    
    i=98 # 99 is current kandel which is not closed, 98 is last closed candel, we need 97 to check if it is bottom or top
    
    if isLCC(prepared_df,i-1)>0:
       # found bottom - OPEN LONG
        if prepared_df['position_in_channel'][i-1]<0.5:
            # close to top of channel
            if prepared_df['slope'][i-1]<-20:
                # found a good enter point for LONG
                signal='long'

    if isHCC(prepared_df,i-1)>0:
       # found top - OPEN SHORT
        if prepared_df['position_in_channel'][i-1]>0.5:
            # close to top of channel
            if prepared_df['slope'][i-1]>20:
                # found a good enter point for SHORT
                signal='short'

    return signal

# %%
def prt(message):
    # telegram message
    print(pointer+': '+message)

# %%
def main(step):
    global proffit_array

    try:
        position=get_opened_positions(symbol)
        open_sl=position[0]
        if open_sl=="": # no position
            prt('Нет открытых позиций')
            # close all stop loss orders
            check_and_close_orders(symbol)
            signal=check_if_signal(symbol)
            proffit_array=copy.copy(eth_proffit_array)

            if signal=='long':
                open_position(symbol,'long',maxposition)

            elif signal=='short':
                open_position(symbol,'short',maxposition)
        else:

            entry_price=position[5] # enter price
            current_price=get_symbol_price(symbol)
            quantity=position[1]

            prt('Найдена открытая позиция '+open_sl)
            prt('Кол-во: '+str(quantity))

            if open_sl=='long':
                stop_price=entry_price*(1-stop_percent)
                if current_price<stop_price:
                    #stop loss
                    close_position(symbol,'long',abs(quantity))
                    proffit_array=copy.copy(eth_proffit_array)
                else:
                    temp_arr=copy.copy(proffit_array)
                    for j in range(0,len(temp_arr)-1):
                        delta=temp_arr[j][0]
                        contracts=temp_arr[j][1]
                        if(current_price>(entry_price+delta)):
                        # take profit
                            close_position(symbol,'long',abs(round(maxposition*(contracts/10),3)))
                            del proffit_array[0]

            if open_sl=='short':
                stop_price=entry_price*(1+stop_percent)
                if current_price>stop_price:
                    #stop loss
                    close_position(symbol,'short',abs(quantity))
                    proffit_array=copy.copy(eth_proffit_array)
                else:
                    temp_arr=copy.copy(proffit_array)
                    for j in range(0,len(temp_arr)-1):
                        delta=temp_arr[j][0]
                        contracts=temp_arr[j][1]
                        if(current_price<(entry_price-delta)):
                        # take profit
                            close_position(symbol,'short',abs(round(maxposition*(contracts/10),3)))
                            del proffit_array[0]
      
    except :
        prt('\n\nSomething went wrong. Continuing...')

# %%
starttime=time.time()
timeout = time.time() + 60*60*12  # 60 seconds times 60 meaning the script will run for 12 hr
counterr=1

while time.time() <= timeout:
    try:
        prt("script continue running at "+time.strftime('%Y-%m-%d %H:%M:%S', time.localtime(time.time())))
        main(counterr)
        counterr=counterr+1
        if counterr>5:
            counterr=1
        time.sleep(10 - ((time.time() - starttime) % 10.0)) # 1 minute interval between each new execution
    except KeyboardInterrupt:
        print('\n\KeyboardInterrupt. Stopping.')
        exit()
# Out:
# 7529: script continue running at 2024-02-15 23:57:36
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-15 23:57:46
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-15 23:57:56
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-15 23:58:06
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-15 23:58:16
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-15 23:58:26
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-15 23:58:36
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-15 23:58:46
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-15 23:58:56
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-15 23:59:06
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-15 23:59:16
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-15 23:59:26
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-15 23:59:36
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-15 23:59:46
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-15 23:59:56
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:00:06
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:00:16
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:00:26
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:00:36
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:00:46
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:00:56
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:01:06
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:01:16
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:01:26
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:01:36
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:01:46
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:01:56
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:02:06
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:02:16
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:02:26
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:02:36
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:02:46
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:02:56
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:03:06
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:03:16
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:03:26
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:03:36
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:03:46
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:03:56
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:04:06
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:04:16
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:04:26
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:04:36
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:04:46
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:04:56
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:05:06
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:05:16
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:05:26
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:05:36
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:05:46
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:05:56
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:06:06
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:06:16
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:06:26
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:06:36
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:06:46
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:06:56
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:07:06
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:07:16
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:07:26
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:07:36
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:07:46
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:07:56
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:08:06
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:08:16
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:08:26
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:08:36
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:08:46
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:08:56
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:09:06
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:09:16
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:09:26
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:09:36
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:09:46
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:09:56
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:10:06
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:10:16
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:10:26
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:10:36
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:10:46
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:10:56
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:11:06
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:11:16
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:11:26
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:11:36
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:11:46
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:11:56
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:12:06
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:12:16
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:12:26
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:12:36
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:12:46
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:12:56
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:13:06
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:13:16
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:13:26
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:13:36
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:13:46
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:13:56
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:14:06
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:14:16
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:14:26
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:14:36
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:14:46
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:14:56
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:15:06
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:15:16
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:15:26
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:15:36
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:15:46
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:15:56
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:16:06
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:16:16
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:16:26
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:16:36
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:16:46
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:16:56
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:17:06
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:17:16
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:17:26
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:17:36
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:17:46
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:17:56
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:18:06
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:18:16
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:18:26
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:18:36
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:18:46
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:18:56
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:19:06
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:19:16
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:19:26
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:19:36
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:19:46
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:19:56
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:20:06
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:20:16
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:20:26
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:20:36
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:20:46
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:20:56
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:21:06
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:21:16
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:21:26
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:21:36
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:21:46
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:21:56
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:22:06
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:22:16
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:22:26
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:22:36
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:22:46
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:22:56
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:23:06
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:23:16
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:23:26
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:23:36
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:23:46
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:23:56
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:24:06
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:24:16
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:24:26
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:24:36
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:24:46
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:24:56
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:25:06
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:25:16
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:25:26
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:25:36
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:25:46
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:25:56
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:26:06
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:26:16
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:26:26
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:26:36
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:26:46
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:26:56
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:27:06
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:27:16
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:27:26
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:27:36
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:27:46
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:27:56
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:28:06
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:28:16
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:28:26
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:28:36
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:28:46
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:28:56
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:29:06
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:29:16
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:29:26
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:29:36
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:29:46
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:29:56
# 7529: Нет открытых позиций
# 7529: script continue running at 2024-02-16 00:30:06
# 7529: Нет открытых позиций
# 7529: open: ETHUSDT quantity: 0.01
# POST https://fapi.binance.com/fapi/v1/batchOrders?batchOrders=%5B%7B%22symbol%22%3A+%22ETHUSDT%22%2C+%22side%22%3A+%22BUY%22%2C+%22type%22%3A+%22LIMIT%22%2C+%22quantity%22%3A+%220.01%22%2C+%22timeInForce%22%3A+%22GTC%22%2C+%22price%22%3A+%222857.29%22%7D%5D&timestamp=1708018209349&signature=7a964eb22e458761c0ef8453f4093acad4a7abbf825c8ac27caf4c51cbaa7e44
# 7529: script continue running at 2024-02-16 00:30:16
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 00:30:26
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 00:30:36
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 00:30:46
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 00:30:56
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 00:31:06
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 00:31:16
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 00:31:26
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 00:31:36
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 00:31:46
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 00:31:56
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 00:32:06
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 00:32:16
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 00:32:26
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 00:32:36
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 00:32:46
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 00:32:56
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 00:33:06
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 00:33:16
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 00:33:26
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 00:33:36
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 00:33:46
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 00:33:56
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 00:34:06
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 00:34:16
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 00:34:26
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 00:34:36
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 00:34:46
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 00:34:56
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 00:35:06
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 00:35:16
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 00:35:26
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 00:35:36
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 00:35:46
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 00:35:56
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 00:36:06
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 00:36:16
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 00:36:26
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 00:36:36
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 00:36:46
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 00:36:56
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 00:37:06
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 00:37:16
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 00:37:26
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 00:37:36
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 00:37:46
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 00:37:56
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 00:38:06
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 00:38:16
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 00:38:26
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 00:38:36
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 00:38:46
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 00:38:56
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 00:39:06
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 00:39:16
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 00:39:26
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 00:39:36
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 00:39:46
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 00:39:56
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 00:40:06
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 00:40:16
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 00:40:26
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 00:40:36
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 00:40:46
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 00:40:56
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 00:41:06
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 00:41:16
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 00:41:26
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 00:41:36
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 00:41:46
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 00:41:56
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 00:42:06
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 00:42:16
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 00:42:26
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 00:42:36
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 00:42:46
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 00:42:56
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 00:43:06
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 00:43:16
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 00:43:26
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 00:43:36
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 00:43:46
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 00:43:56
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 00:44:06
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 00:44:16
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 00:44:26
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 00:44:36
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 00:44:46
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 00:44:56
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 00:45:06
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 00:45:16
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 00:45:26
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 00:45:36
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 00:45:46
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 00:45:56
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 00:46:06
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 00:46:16
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 00:46:26
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 00:46:36
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 00:46:46
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 00:46:56
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 00:47:06
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 00:47:16
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 00:47:26
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 00:47:36
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 00:47:46
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 00:47:56
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 00:48:06
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 00:48:16
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 00:48:26
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 00:48:36
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 00:48:46
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 00:48:56
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 00:49:06
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 00:49:16
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 00:49:26
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 00:49:36
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 00:49:46
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 00:49:56
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 00:50:06
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 00:50:16
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 00:50:26
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 00:50:36
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 00:50:46
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 00:50:56
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 00:51:06
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 00:51:16
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 00:51:26
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 00:51:36
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 00:51:46
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 00:51:56
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 00:52:06
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 00:52:16
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 00:52:26
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 00:52:36
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 00:52:46
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 00:52:56
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 00:53:06
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 00:53:16
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 00:53:26
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 00:53:36
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 00:53:46
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 00:53:56
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 00:54:06
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 00:54:16
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 00:54:26
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 00:54:36
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 00:54:46
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 00:54:56
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 00:55:06
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 00:55:16
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 00:55:26
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 00:55:36
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 00:55:46
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 00:55:56
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 00:56:06
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 00:56:16
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 00:56:26
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 00:56:36
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 00:56:46
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 00:56:56
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 00:57:06
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 00:57:16
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 00:57:26
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 00:57:36
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 00:57:46
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 00:57:56
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 00:58:06
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 00:58:16
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 00:58:26
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 00:58:36
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 00:58:46
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 00:58:56
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 00:59:06
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 00:59:16
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 00:59:26
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 00:59:36
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 00:59:46
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 00:59:56
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:00:06
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:00:16
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:00:26
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:00:36
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:00:46
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:00:56
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:01:06
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:01:16
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:01:26
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:01:36
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:01:46
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:01:56
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:02:06
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:02:16
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:02:26
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:02:36
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:02:46
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:02:56
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:03:06
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:03:16
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:03:26
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:03:36
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:03:46
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:03:56
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:04:06
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:04:16
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:04:26
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:04:36
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:04:46
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:04:56
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:05:06
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:05:16
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:05:26
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:05:36
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:05:46
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:05:56
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:06:06
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:06:16
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:06:26
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:06:36
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:06:46
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:06:56
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:07:06
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:07:16
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:07:26
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:07:36
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:07:46
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:07:56
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:08:06
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:08:16
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:08:26
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:08:36
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:08:46
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:08:56
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:09:06
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:09:16
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:09:26
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:09:36
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:09:46
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:09:56
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:10:06
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:10:16
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:10:26
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:10:36
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:10:46
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:10:56
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:11:06
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:11:16
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:11:26
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:11:36
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:11:46
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:11:56
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:12:06
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:12:16
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:12:26
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:12:36
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:12:46
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:12:56
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:13:06
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:13:16
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:13:26
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:13:36
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:13:46
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:13:56
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:14:06
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:14:16
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:14:26
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:14:36
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:14:46
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:14:56
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:15:06
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:15:16
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:15:26
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:15:36
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:15:46
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:15:56
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:16:06
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:16:16
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:16:26
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:16:36
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:16:46
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:16:56
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:17:06
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:17:16
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:17:26
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:17:36
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:17:46
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:17:56
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:18:06
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:18:16
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:18:26
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:18:36
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:18:46
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:18:56
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:19:06
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:19:16
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:19:26
# ...
# 7529: script continue running at 2024-02-16 01:36:06
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:36:16
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:36:26
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:36:36
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:36:46
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:36:56
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:37:06
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:37:16
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:37:26
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:37:36
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:37:46
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:37:56
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:38:06
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:38:16
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:38:26
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:38:36
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:38:46
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:38:56
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:39:06
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:39:16
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:39:26
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:39:36
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:39:46
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:39:56
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:40:06
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:40:16
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:40:26
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:40:36
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:40:46
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:40:56
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:41:06
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:41:16
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:41:26
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:41:36
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:41:46
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:41:56
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:42:06
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:42:16
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:42:26
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:42:36
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:42:46
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:42:56
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:43:06
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:43:16
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:43:26
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:43:36
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:43:46
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:43:56
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:44:06
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:44:16
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:44:26
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:44:36
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:44:46
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:44:56
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:45:06
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:45:16
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:45:26
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:45:36
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:45:46
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:45:56
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:46:06
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:46:16
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:46:26
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:46:36
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:46:46
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:46:56
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:47:06
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:47:16
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:47:26
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:47:36
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:47:46
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:47:56
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:48:06
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:48:16
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:48:26
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:48:36
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:48:46
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:48:56
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:49:06
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:49:16
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:49:26
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:49:36
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:49:46
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:49:56
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:50:06
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:50:16
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:50:26
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:50:36
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:50:46
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:50:56
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:51:06
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:51:16
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:51:26
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:51:36
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:51:46
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:51:56
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:52:06
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:52:16
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:52:26
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:52:36
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:52:46
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:52:56
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:53:06
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:53:16
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:53:26
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:53:36
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:53:46
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:53:56
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:54:06
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:54:16
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:54:26
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:54:36
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:54:46
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:54:56
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:55:06
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:55:16
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:55:26
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:55:36
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:55:46
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:55:56
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:56:06
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:56:16
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:56:26
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:56:36
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:56:46
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:56:56
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:57:06
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:57:16
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:57:26
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:57:36
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:57:46
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:57:56
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:58:06
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:58:16
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:58:26
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:58:36
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:58:46
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:58:56
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:59:06
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:59:16
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:59:26
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:59:36
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:59:46
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 01:59:56
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 02:00:06
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 02:00:16
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 02:00:26
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
# 7529: script continue running at 2024-02-16 02:00:36
# 7529: Найдена открытая позиция long
# 7529: Кол-во: 0.01
